# %%
import torch
import torch.nn.functional as F

"""for batch train"""
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

import pandas as pd

# %%
class Mydata(Dataset):
    """
    For torch, 
    Batch Train
    """
    def __init__(self) -> None:
        super().__init__()
        self.x_data = [
            [10,20],
            [30,40],
            [33,43],
            [50,60],
            [70,80],
            [90,92]
            ]
        self.y_data = [
            [100],
            [110],
            [115],
            [130],
            [135],
            [140],
            ]
    
    def __len__(self):
        """
        data length
        """
        return len(self.x_data)
    
    def __getitem__(self, index):
        """
        data => torch.FloatTensor
        """
        x = torch.FloatTensor(self.x_data[index])
        y = torch.FloatTensor(self.y_data[index])
        return x,y

# %%
dataset = Mydata()
dataloader = DataLoader(dataset, batch_size=3, shuffle=True)

# %%
model = torch.nn.Linear(in_features=2, out_features=1)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
from sklearn.metrics import mean_squared_error

# %%
for epoch in range(10):
    for batch_idx, samples in enumerate(dataloader):
        print(f'batch_idx : {batch_idx}')
        print(f'samples : \n{samples[0]} \n {samples[1]}')
        print('='*10)
        x_train, y_train = samples
        
        hx = model.forward(x_train)
        cost = F.mse_loss(hx,y_train)
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()
        print(f'epoch => {epoch} / cost : {cost.item()} / \
            MSE : {mean_squared_error(hx.detach().numpy(),y_train.detach().numpy())}')
        # print(f'epoch => {epoch} / cost : {cost.item()}')
    print('='*100)
# Out:
# batch_idx : 0
# samples :
# tensor([[50., 60.],
#         [90., 92.],
#         [33., 43.]])
#  tensor([[130.],
#         [140.],
#         [115.]])
# ==========
# epoch => 0 / cost : 37700.81640625 /             MSE : 37700.81640625
# batch_idx : 1
# samples :
# tensor([[70., 80.],
#         [30., 40.],
#         [10., 20.]])
#  tensor([[135.],
#         [110.],
#         [100.]])
# ==========
# epoch => 0 / cost : 26377.927734375 /             MSE : 26377.927734375
# ====================================================================================================
# batch_idx : 0
# samples :
# tensor([[90., 92.],
#         [70., 80.],
#         [30., 40.]])
#  tensor([[140.],
#         [135.],
#         [110.]])
# ==========
# epoch => 1 / cost : 39152.06640625 /             MSE : 39152.06640625
# batch_idx : 1
# samples :
# tensor([[50., 60.],
#         [33., 43.],
#         [10., 20.]])
#  tensor([[130.],
#         [115.],
#         [100.]])
# ==========
# epoch => 1 / cost : 23425.2578125 /             MSE : 23425.2578125
# ====================================================================================================
# batch_idx : 0
# samples :
# tensor([[10., 20.],
#         [30., 40.],
#         [70., 80.]])
#  tensor([[100.],
#         [110.],
#         [135.]])
# ==========
# epoch => 2 / cost : 25510.568359375 /             MSE : 25510.568359375
# batch_idx : 1
# samples :
# tensor([[33., 43.],
#         [50., 60.],
#         [90., 92.]])
#  tensor([[115.],
#         [130.],
#         [140.]])
# ==========
# epoch => 2 / cost : 35335.8125 /             MSE : 35335.8125
# ====================================================================================================
# batch_idx : 0
# samples :
# tensor([[10., 20.],
#         [33., 43.],
#         [30., 40.]])
#  tensor([[100.],
#         [115.],
#         [110.]])
# ==========
# epoch => 3 / cost : 18672.376953125 /             MSE : 18672.376953125
# batch_idx : 1
# samples :
# tensor([[70., 80.],
#         [50., 60.],
#         [90., 92.]])
#  tensor([[135.],
#         [130.],
#         [140.]])
# ==========
# epoch => 3 / cost : 40609.9453125 /             MSE : 40609.9453125
# ====================================================================================================
# batch_idx : 0
# samples :
# tensor([[10., 20.],
#         [30., 40.],
#         [70., 80.]])
#  tensor([[100.],
#         [110.],
#         [135.]])
# ==========
# epoch => 4 / cost : 24411.974609375 /             MSE : 24411.974609375
# batch_idx : 1
# samples :
# tensor([[90., 92.],
#         [50., 60.],
#         [33., 43.]])
#  tensor([[140.],
#         [130.],
#         [115.]])
# ==========
# epoch => 4 / cost : 33560.640625 /             MSE : 33560.640625
# ====================================================================================================
# batch_idx : 0
# samples :
# tensor([[50., 60.],
#         [70., 80.],
#         [30., 40.]])
#  tensor([[130.],
#         [135.],
#         [110.]])
# ==========
# epoch => 5 / cost : 29955.931640625 /             MSE : 29955.931640625
# batch_idx : 1
# samples :
# tensor([[10., 20.],
#         [33., 43.],
#         [90., 92.]])
#  tensor([[100.],
#         [115.],
#         [140.]])
# ==========
# epoch => 5 / cost : 26688.677734375 /             MSE : 26688.677734375
# ====================================================================================================
# batch_idx : 0
# samples :
# tensor([[50., 60.],
#         [10., 20.],
#         [90., 92.]])
#  tensor([[130.],
#         [100.],
#         [140.]])
# ==========
# epoch => 6 / cost : 29379.326171875 /             MSE : 29379.326171875
# batch_idx : 1
# samples :
# tensor([[70., 80.],
#         [30., 40.],
#         [33., 43.]])
#  tensor([[135.],
#         [110.],
#         [115.]])
# ==========
# epoch => 6 / cost : 25860.966796875 /             MSE : 25860.966796875
# ====================================================================================================
# batch_idx : 0
# samples :
# tensor([[10., 20.],
#         [70., 80.],
#         [90., 92.]])
#  tensor([[100.],
#         [135.],
#         [140.]])
# ==========
# epoch => 7 / cost : 31031.111328125 /             MSE : 31031.111328125
# batch_idx : 1
# samples :
# tensor([[30., 40.],
#         [50., 60.],
#         [33., 43.]])
#  tensor([[110.],
#         [130.],
#         [115.]])
# ==========
# epoch => 7 / cost : 22861.896484375 /             MSE : 22861.896484375
# ====================================================================================================
# batch_idx : 0
# samples :
# tensor([[70., 80.],
#         [50., 60.],
#         [10., 20.]])
#  tensor([[135.],
#         [130.],
#         [100.]])
# ==========
# epoch => 8 / cost : 25744.681640625 /             MSE : 25744.681640625
# batch_idx : 1
# samples :
# tensor([[30., 40.],
#         [90., 92.],
#         [33., 43.]])
#  tensor([[110.],
#         [140.],
#         [115.]])
# ==========
# epoch => 8 / cost : 26647.283203125 /             MSE : 26647.283203125
# ====================================================================================================
# batch_idx : 0
# samples :
# tensor([[10., 20.],
#         [33., 43.],
#         [90., 92.]])
#  tensor([[100.],
#         [115.],
#         [140.]])
# ==========
# epoch => 9 / cost : 24364.146484375 /             MSE : 24364.146484375
# batch_idx : 1
# samples :
# tensor([[50., 60.],
#         [30., 40.],
#         [70., 80.]])
#  tensor([[130.],
#         [110.],
#         [135.]])
# ==========
# epoch => 9 / cost : 26680.728515625 /             MSE : 26680.728515625
# ====================================================================================================

# %%
hx.detach().numpy()
# Out:
# array([[-7.709188],
#        [-6.142795]], dtype=float32)

# %%
y_train
# Out:
# tensor([[50., 60.],
#         [30., 40.]])
