# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv( '../../raw_data/test.csv', header=None)
df.columns = ['q1','q2','mid','final']
df
# Out:
#     q1  q2  mid  final
# 0   73  80   75    152
# 1   93  88   93    185
# 2   89  91   90    180
# 3   96  98  100    196
# 4   73  66   70    142
# 5   53  46   55    101
# 6   69  74   77    149
# 7   47  56   60    115
# 8   87  79   90    175
# 9   79  70   88    164
# 10  69  70   73    141
# 11  70  65   74    141
# 12  93  95   91    184
# 13  79  80   73    152
# 14  70  73   78    148
# 15  93  89   96    192
# 16  78  75   68    147
# 17  81  90   93    183
# 18  88  92   86    177
# 19  78  83   77    159
# 20  82  86   90    177
# 21  86  82   89    175
# 22  78  83   85    175
# 23  76  83   71    149
# 24  96  93   95    192

# %%
x_data = df.iloc[:, :-1]
y_data = df.iloc[:, [-1] ]

# %%
x_data
# Out:
#     q1  q2  mid
# 0   73  80   75
# 1   93  88   93
# 2   89  91   90
# 3   96  98  100
# 4   73  66   70
# 5   53  46   55
# 6   69  74   77
# 7   47  56   60
# 8   87  79   90
# 9   79  70   88
# 10  69  70   73
# 11  70  65   74
# 12  93  95   91
# 13  79  80   73
# 14  70  73   78
# 15  93  89   96
# 16  78  75   68
# 17  81  90   93
# 18  88  92   86
# 19  78  83   77
# 20  82  86   90
# 21  86  82   89
# 22  78  83   85
# 23  76  83   71
# 24  96  93   95

# %%
x_data.shape
# Out:
# (25, 3)

# %%
x = tf.constant( x_data, tf.float32)
y = tf.constant( y_data, tf.float32)
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-11-30 20:32:42.841746: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-30 20:32:42.841919: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
w = tf.Variable( tf.random.uniform([3,1]) )#[특성데이터갯수, 라벨의갯수]
b = tf.Variable( tf.random.uniform([1]) ) # 라벨의 갯수

# %%
def cost():
#     hx = x1*w1 + x2*w2 + x3*w3 +  b
    hx = tf.matmul( x, w ) + b
    c = tf.reduce_mean( (hx-y)**2)
    return c

# %%
optimizer = Adam( learning_rate=0.1 )
hist_cost=[]
for i in range( 1000):
    optimizer.minimize( cost, var_list=[w,b] )
    c = cost().numpy()
    hist_cost.append( c )
    print( i, 'cost=', c )
# Out:
# 0 cost= 11.630381
# 1 cost= 284.43503
# 2 cost= 282.3872
# 3 cost= 94.820015
# 4 cost= 8.150294
# 5 cost= 78.2451
# 6 cost= 159.58302
# 7 cost= 141.48706
# 8 cost= 62.1154
# 9 cost= 10.209518
# 10 cost= 26.063435
# 11 cost= 73.47902
# 12 cost= 91.43082
# 13 cost= 63.53328
# 14 cost= 22.86442
# 15 cost= 8.250156
# 16 cost= 26.31606
# 17 cost= 50.046967
# 18 cost= 51.74615
# 19 cost= 31.470043
# 20 cost= 11.431737
# 21 cost= 9.91117
# 22 cost= 23.545862
# 23 cost= 33.957542
# 24 cost= 29.376513
# 25 cost= 15.896586
# 26 cost= 8.026978
# 27 cost= 12.08891
# 28 cost= 20.666267
# 29 cost= 22.701271
# 30 cost= 16.231457
# 31 cost= 9.083476
# 32 cost= 8.6357155
# 33 cost= 13.608857
# 34 cost= 16.801361
# 35 cost= 14.286832
# 36 cost= 9.4555435
# 37 cost= 7.899842
# 38 cost= 10.48165
# 39 cost= 13.016303
# 40 cost= 12.091448
# 41 cost= 9.097538
# 42 cost= 7.7648497
# 43 cost= 9.1853285
# 44 cost= 10.853176
# 45 cost= 10.383711
# 46 cost= 8.527793
# 47 cost= 7.7102747
# 48 cost= 8.629448
# ...

# %%
w
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[0.35690823],
#        [0.53778476],
#        [1.1511304 ]], dtype=float32)>

# %%
def hxFn( xdata ):
    hx = tf.matmul( xdata, w ) + b
    return hx.numpy()

# %%
## q1:80, q2:90, mid:90 최종점수를 예측하시요.
hxFn([[80.,90.,90.]])
# Out:
# array([[177.8795]], dtype=float32)
