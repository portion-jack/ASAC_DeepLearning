# %%
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras.preprocessing.image as p
plt.rc('font',family='AppleGothic')

# %%
img_gen = p.ImageDataGenerator(rescale= 1./255.)
imgs = img_gen.flow_from_directory('./img_data/',target_size=(256,256))
x_train,y_train=imgs.next()

labels=imgs.class_indices.keys()

y_dict = {0:list(labels)[0],
          1:list(labels)[1],
          2:list(labels)[2],
          3:list(labels)[3],
          4:list(labels)[4]
          }

plt.imshow(x_train[0])
plt.title(y_dict[y_train[0].argmax()])
plt.show()
# Out:
# Found 486 images belonging to 5 classes.

# %%
print(f'x_train.shape => {x_train.shape}')
print(f'y_train.shape => {y_train.shape}')
# Out:
# x_train.shape => (32, 256, 256, 3)
# y_train.shape => (32, 5)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(
    filters=32,
    kernel_size=(5,5),
    strides=1,
    activation='relu',
    padding='same',
    input_shape=(256,256,3)
))

model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2,2),
    input_shape=(252,252,32)
))

model.add(tf.keras.layers.Conv2D(
    filters=16,
    kernel_size=(5,5),
    strides=1,
    activation='relu',
    padding='same',
    input_shape=(62,62,32)
))
model.add(tf.keras.layers.Flatten()) 
model.add(tf.keras.layers.Dense(units=64, activation='relu'))
model.add(tf.keras.layers.Dense(units=5, activation='softmax'))
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-12-13 15:55:28.208249: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-12-13 15:55:28.208384: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["acc"])

# %%
hist=model.fit(imgs,epochs=32,validation_data=[x_train,y_train])
# Out:
# Epoch 1/32
# 2022-12-13 15:55:28.452725: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-12-13 15:55:28.629898: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 3s 188ms/step - loss: 2.7655 - acc: 0.2387 - val_loss: 2.6409 - val_acc: 0.1250
# Epoch 2/32
# 2022-12-13 15:55:31.654208: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 3s 182ms/step - loss: 1.5548 - acc: 0.3971 - val_loss: 1.4444 - val_acc: 0.5625
# Epoch 3/32
# 16/16 [==============================] - 3s 181ms/step - loss: 1.4029 - acc: 0.4465 - val_loss: 1.2985 - val_acc: 0.6875
# Epoch 4/32
# 16/16 [==============================] - 3s 180ms/step - loss: 1.2194 - acc: 0.5679 - val_loss: 0.9027 - val_acc: 0.7188
# Epoch 5/32
# 16/16 [==============================] - 3s 182ms/step - loss: 0.7183 - acc: 0.7695 - val_loss: 0.4263 - val_acc: 0.8750
# Epoch 6/32
# 16/16 [==============================] - 3s 182ms/step - loss: 0.2709 - acc: 0.9218 - val_loss: 0.1594 - val_acc: 0.9688
# Epoch 7/32
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0587 - acc: 0.9856 - val_loss: 0.0287 - val_acc: 1.0000
# Epoch 8/32
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0116 - acc: 0.9979 - val_loss: 0.0040 - val_acc: 1.0000
# Epoch 9/32
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0267 - acc: 0.9938 - val_loss: 0.0216 - val_acc: 1.0000
# Epoch 10/32
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0745 - acc: 0.9918 - val_loss: 0.0245 - val_acc: 1.0000
# Epoch 11/32
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0236 - acc: 0.9979 - val_loss: 0.0323 - val_acc: 1.0000
# Epoch 12/32
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0178 - acc: 0.9979 - val_loss: 0.0018 - val_acc: 1.0000
# Epoch 13/32
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0045 - acc: 0.9979 - val_loss: 3.3409e-04 - val_acc: 1.0000
# Epoch 14/32
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 2.9274e-04 - val_acc: 1.0000
# Epoch 15/32
# 16/16 [==============================] - 3s 188ms/step - loss: 4.1569e-04 - acc: 1.0000 - val_loss: 1.5538e-04 - val_acc: 1.0000
# Epoch 16/32
# 16/16 [==============================] - 3s 181ms/step - loss: 2.0287e-04 - acc: 1.0000 - val_loss: 1.0503e-04 - val_acc: 1.0000
# Epoch 17/32
# 16/16 [==============================] - 3s 181ms/step - loss: 1.2419e-04 - acc: 1.0000 - val_loss: 7.9265e-05 - val_acc: 1.0000
# Epoch 18/32
# 16/16 [==============================] - 3s 180ms/step - loss: 9.9189e-05 - acc: 1.0000 - val_loss: 6.7792e-05 - val_acc: 1.0000
# Epoch 19/32
# 16/16 [==============================] - 3s 182ms/step - loss: 8.4079e-05 - acc: 1.0000 - val_loss: 5.6973e-05 - val_acc: 1.0000
# Epoch 20/32
# 16/16 [==============================] - 3s 181ms/step - loss: 7.0795e-05 - acc: 1.0000 - val_loss: 4.9296e-05 - val_acc: 1.0000
# Epoch 21/32
# 16/16 [==============================] - 3s 181ms/step - loss: 6.1219e-05 - acc: 1.0000 - val_loss: 4.2454e-05 - val_acc: 1.0000
# Epoch 22/32
# 16/16 [==============================] - 3s 181ms/step - loss: 5.4833e-05 - acc: 1.0000 - val_loss: 3.8505e-05 - val_acc: 1.0000
# Epoch 23/32
# 16/16 [==============================] - 3s 180ms/step - loss: 4.9799e-05 - acc: 1.0000 - val_loss: 3.5172e-05 - val_acc: 1.0000
# Epoch 24/32
# 16/16 [==============================] - 3s 181ms/step - loss: 4.4897e-05 - acc: 1.0000 - val_loss: 3.2528e-05 - val_acc: 1.0000
# Epoch 25/32
# 16/16 [==============================] - 3s 181ms/step - loss: 4.1379e-05 - acc: 1.0000 - val_loss: 3.0304e-05 - val_acc: 1.0000
# Epoch 26/32
# 16/16 [==============================] - 3s 184ms/step - loss: 3.7136e-05 - acc: 1.0000 - val_loss: 2.8427e-05 - val_acc: 1.0000
# Epoch 27/32
# 16/16 [==============================] - 3s 182ms/step - loss: 3.4312e-05 - acc: 1.0000 - val_loss: 2.6565e-05 - val_acc: 1.0000
# Epoch 28/32
# 16/16 [==============================] - 3s 181ms/step - loss: 3.2001e-05 - acc: 1.0000 - val_loss: 2.4822e-05 - val_acc: 1.0000
# Epoch 29/32
# 16/16 [==============================] - 3s 181ms/step - loss: 2.9345e-05 - acc: 1.0000 - val_loss: 2.3676e-05 - val_acc: 1.0000
# Epoch 30/32
# 16/16 [==============================] - 3s 185ms/step - loss: 2.7497e-05 - acc: 1.0000 - val_loss: 2.2313e-05 - val_acc: 1.0000
# Epoch 31/32
# 16/16 [==============================] - 3s 182ms/step - loss: 2.5677e-05 - acc: 1.0000 - val_loss: 2.1267e-05 - val_acc: 1.0000
# Epoch 32/32
# 16/16 [==============================] - 3s 183ms/step - loss: 2.4049e-05 - acc: 1.0000 - val_loss: 2.0239e-05 - val_acc: 1.0000

# %%
plt.imshow(x_train[6])
plt.title(y_dict[model.predict(x_train[6].reshape(1,256,256,3)).argmax()])
# Out:
# 1/1 [==============================] - 0s 65ms/step
# 2022-12-13 15:57:04.025521: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Text(0.5, 1.0, '츄리닝패션')

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'],'--r')
plt.show()

# %%
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'],'--r')
plt.show()

# %%
model.save('fashion_cnn_main.h5')

# %%
type(hist.history)
# Out:
# dict

# %%
import pickle

with open('model_hist.pickle', 'wb') as f:
    pickle.dump(hist.history, f)

# %%
plt.imshow(x_train[11])

# %%
from keras.models import Model
layer_outputs = [layer.output for layer in model.layers]
activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(x_train[11].reshape(1,256,256,3))
 
def display_activation(activations, col_size, row_size, act_index): 
    activation = activations[act_index]
    activation_index=0
    fig, ax = plt.subplots(row_size, col_size, figsize=(row_size*3,col_size*2))
    for row in range(0,row_size):
        for col in range(0,col_size):
            ax[row][col].imshow(activation[0, :, :, activation_index], cmap='gray')
            activation_index += 1
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 2022-12-13 15:58:45.758634: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
display_activation(activations, 4, 4, 2)
